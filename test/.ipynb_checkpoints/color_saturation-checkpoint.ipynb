# %%
import cv2
import sys
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
def MoveSmooth(now_frame, before_frame = None, alpha = 0.5, beta = 0.5):
    if before_frame is None:
        return now_frame
    return alpha * now_frame + before_frame * beta

# %%
path = r'H:\DATASET\COLORDATA/001/'

# %%
path+'f025.png'
# Out:
# 'H:\\DATASET\\COLORDATA/001/f025.png'

# %%
img = cv2.imread(path+'f025.png')
img = np.array(img, dtype = np.uint16)

# %%
cv2.imwrite('./a.png', np.array((img + img)/2, dtype = np.uint8))
# Out:
# True

# %%
save_path = r'H:\DATASET\COLORDATA/001/'
for (root, dirs, files) in os.walk(path):
    now_dir = path.split('/')[-1]
    index = 0
    for index_file in files:
        if index_file[-3:] != 'png':
            break
        image_path = root + '/' + index_file
        img = cv2.imread(image_path)
        img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
        if index:
            img_new = MoveSmooth(img, old_img)
        else:
            img_new = MoveSmooth(img)
        old_img = img_new
        img_new = cv2.cvtColor( np.array(img_new * 255, dtype=np.uint8), cv2.COLOR_BGR2RGB)
        image_path_saved = '{}{}/{}'.format(save_path,now_dir,index_file)
        cv2.imwrite(image_path_saved, img_new)
        print(image_path_saved)
        index += 1

# %%
def PSAlgorithm(rgb_img, increment):
    img = rgb_img * 1.0
    img_min = img.min(axis=2)
    img_max = img.max(axis=2)
    img_out = img
    delta = (img_max - img_min) / 255.0
    value = (img_max + img_min) / 255.0
    L = value/2.0
    mask_1 = L < 0.5
    if value == 0 :
        s1 = 0.5
    else:
        s1 = delta/(value)
    if value == 2:
        s2 = 0.5
    else:
        s2 = delta/(2 - value)
    s = s1 * mask_1 + s2 * (1 - mask_1)
    if increment >= 0:
        temp = increment + s
        mask_2 = temp > 1
        alpha_1 = s
        alpha_2 = s * 0 + 1 - increment
        alpha = alpha_1 * mask_2 + alpha_2 * (1 - mask_2)
        alpha = 1/alpha -1
        img_out[:, :, 0] = img[:, :, 0] + (img[:, :, 0] - L * 255.0) * alpha
        img_out[:, :, 1] = img[:, :, 1] + (img[:, :, 1] - L * 255.0) * alpha
        img_out[:, :, 2] = img[:, :, 2] + (img[:, :, 2] - L * 255.0) * alpha
    else:
        alpha = increment
        img_out[:, :, 0] = img[:, :, 0] + (img[:, :, 0] - L * 255.0) * alpha
        img_out[:, :, 1] = img[:, :, 1] + (img[:, :, 1] - L * 255.0) * alpha
        img_out[:, :, 2] = img[:, :, 2] + (img[:, :, 2] - L * 255.0) * alpha
    img_out = img_out/255.0
    # RGB颜色上下限处理(小于0取0，大于1取1)
    mask_3 = img_out < 0
    mask_4 = img_out > 1
    img_out = img_out * (1-mask_3)
    img_out = img_out * (1-mask_4) + mask_4
    return img_out

# %%
path = r'H:\DATASET\COLORDATA'

# %%
for (root, dirs, files) in os.walk(path):
    now_dir = root.split('\\')[-1]
    print(now_dir)
# Out:
# COLORDATA
# 001
# 002
# archive
# ab
# ab
# l
# train
# train
# train_frame
# 001
# 002
# 003
# 004
# 005
# 006
# 007
# 008
# 009
# 010
# 011
# 012
# 013
# 014
# 015
# 016
# 017
# 018
# 019
# 020
# 021
# 022
# 023
# 024
# 025
# 026
# 027
# 028
# 029
# 030
# 031
# 032
# 033
# 034
# 035
# 036
# 037
# 038
# 039
# 040
# 041
# 042
# 043
# 044
# 045
# 046
# 047
# 048
# 049
# 050
# 051
# 052
# 053
# 054
# 055
# 056
# 057
# 058
# 059
# 060
# 061
# 062
# 063
# 064
# 065
# 066
# 067
# 068
# 069
# 070
# 071
# 072
# 073
# 074
# 075
# 076
# 077
# 078
# 079
# 080
# 081
# 082
# 083
# 084
# 085
# 086
# 087
# 088
# 089
# 090
# 091
# 092
# 093
# 094
# 095
# 096
# 097
# 098
# 099
# 100
# 101
# 102
# 103
# 104
# 105
# 106
# 107
# 108
# 109
# 110
# 111
# 112
# 113
# 114
# 115
# 116
# 117
# 118
# 119
# 120
# 121
# 122
# 123
# 124
# 125
# 126
# 127
# 128
# 129
# 130
# 131
# 132
# 133
# 134
# 135
# 136
# 137
# 138
# 139
# 140
# 141
# 142
# 143
# 144
# 145
# 146
# 147
# 148
# 149
# 150
# 151
# 152
# 153
# 154
# 155
# 156
# 157
# 158
# 159
# 160
# 161
# 162
# 163
# 164
# 165
# 166
# 167
# 168
# 169
# 170
# 171
# 172
# 173
# 174
# 175
# 176
# 177
# 178
# 179
# 180
# 181
# 182
# 183
# 184
# 185
# 186
# 187
# 188
# 189
# 190
# 191
# 192
# 193
# 194
# 195
# 196
# 197
# 198
# 199
# 200
# train_gt
# train_gt
# train_gt_frame
# 001
# 002
# 003
# 004
# 005
# 006
# 007
# 008
# 009
# 010
# 011
# 012
# 013
# 014
# 015
# 016
# 017
# 018
# 019
# 020
# 021
# 022
# 023
# 024
# 025
# 026
# 027
# 028
# 029
# 030
# 031
# 032
# 033
# 034
# 035
# 036
# 037
# 038
# 039
# 040
# 041
# 042
# 043
# 044
# 045
# 046
# 047
# 048
# 049
# 050
# 051
# 052
# 053
# 054
# 055
# 056
# 057
# 058
# 059
# 060
# 061
# 062
# 063
# 064
# 065
# 066
# 067
# 068
# 069
# 070
# 071
# 072
# 073
# 074
# 075
# 076
# 077
# 078
# 079
# 080
# 081
# 082
# 083
# 084
# 085
# 086
# 087
# 088
# 089
# 090
# 091
# 092
# 093
# 094
# 095
# 096
# 097
# 098
# 099
# 100
# 101
# 102
# 103
# 104
# 105
# 106
# 107
# 108
# 109
# 110
# 111
# 112
# 113
# 114
# 115
# 116
# 117
# 118
# 119
# 120
# 121
# 122
# 123
# 124
# 125
# 126
# 127
# 128
# 129
# 130
# 131
# 132
# 133
# 134
# 135
# 136
# 137
# 138
# 139
# 140
# 141
# 142
# 143
# 144
# 145
# 146
# 147
# 148
# 149
# 150
# 151
# 152
# 153
# 154
# 155
# 156
# 157
# 158
# 159
# 160
# 161
# 162
# 163
# 164
# 165
# 166
# 167
# 168
# 169
# 170
# 171
# 172
# 173
# 174
# 175
# 176
# 177
# 178
# 179
# 180
# 181
# 182
# 183
# 184
# 185
# 186
# 187
# 188
# 189
# 190
# 191
# 192
# 193
# 194
# 195
# 196
# 197
# 198
# 199
# 200
# val
# val
# val_frame
# 001
# 002
# 003
# 004
# 005
# 006
# 007
# 008
# 009
# 010
# 011
# 012
# 013
# 014
# 015

# %%
increment = 0.5
save_path = r'H:\DATASET\COLORDATA/002/'
for (root, dirs, files) in os.walk(path):
    now_dir = path.split('/')[-1]
    for index_file in files:
        if index_file[-3:] != 'png':
            break
        image_path = root + index_file
        img = cv2.imread(image_path)
        img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
        img_new = PSAlgorithm(img, increment)
        img_new = cv2.cvtColor( np.array(img_new * 255, dtype=np.uint8), cv2.COLOR_BGR2RGB)
        image_path_saved = '{}{}/{}'.format(save_path,now_dir,index_file)
        cv2.imwrite(image_path_saved, img_new)
        print(image_path_saved)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20084\3339006431.py:10: RuntimeWarning: invalid value encountered in divide
#   s1 = delta/(value)
# C:\Users\HP\AppData\Local\Temp\ipykernel_20084\3339006431.py:11: RuntimeWarning: invalid value encountered in divide
#   s2 = delta/(2 - value)
# H:\DATASET\COLORDATA/002//f025.png
# H:\DATASET\COLORDATA/002//f026.png
# H:\DATASET\COLORDATA/002//f027.png
# H:\DATASET\COLORDATA/002//f028.png
# H:\DATASET\COLORDATA/002//f029.png
# H:\DATASET\COLORDATA/002//f030.png
# H:\DATASET\COLORDATA/002//f031.png
# H:\DATASET\COLORDATA/002//f032.png
# H:\DATASET\COLORDATA/002//f033.png
# H:\DATASET\COLORDATA/002//f034.png
# H:\DATASET\COLORDATA/002//f035.png
# H:\DATASET\COLORDATA/002//f036.png
# H:\DATASET\COLORDATA/002//f037.png
# H:\DATASET\COLORDATA/002//f038.png
# H:\DATASET\COLORDATA/002//f039.png
# H:\DATASET\COLORDATA/002//f040.png
# H:\DATASET\COLORDATA/002//f041.png
# H:\DATASET\COLORDATA/002//f042.png
# H:\DATASET\COLORDATA/002//f043.png
# H:\DATASET\COLORDATA/002//f044.png
# H:\DATASET\COLORDATA/002//f045.png
# H:\DATASET\COLORDATA/002//f046.png
# H:\DATASET\COLORDATA/002//f047.png
# H:\DATASET\COLORDATA/002//f048.png
# H:\DATASET\COLORDATA/002//f049.png
# H:\DATASET\COLORDATA/002//f050.png
# H:\DATASET\COLORDATA/002//f051.png
# H:\DATASET\COLORDATA/002//f052.png
# H:\DATASET\COLORDATA/002//f053.png
# H:\DATASET\COLORDATA/002//f054.png
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [59], in <cell line: 3>()
#       9 img = cv2.imread(image_path)
#      10 img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
# ---> 11 img_new = PSAlgorithm(img, increment)
#      12 img_new = cv2.cvtColor( np.array(img_new * 255, dtype=np.uint8), cv2.COLOR_BGR2RGB)
#      13 image_path_saved = '{}{}/{}'.format(save_path,now_dir,index_file)
#
# Input In [3], in PSAlgorithm(rgb_img, increment)
#       2 img = rgb_img * 1.0
#       3 img_min = img.min(axis=2)
# ----> 4 img_max = img.max(axis=2)
#       5 img_out = img
#       6 delta = (img_max - img_min) / 255.0
#
# File E:\anaconda\envs\DSIM\lib\site-packages\numpy\core\_methods.py:40, in _amax(a, axis, out, keepdims, initial, where)
#      38 def _amax(a, axis=None, out=None, keepdims=False,
#      39           initial=_NoValue, where=True):
# ---> 40     return umr_maximum(a, axis, None, out, keepdims, initial, where)
#
# KeyboardInterrupt:

# %%
path = r'H:\DATASET\COLORDATA\001/f001.png'
increment = 0.5 # 范围-1到1
img = cv2.imread(path)
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
img_new = PSAlgorithm(img, increment)
plt.figure("img_original")
plt.imshow(img/255.0)
plt.axis('off')
plt.figure("img_saturate")
plt.imshow(img_new)
plt.axis('off')
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20084\3339006431.py:10: RuntimeWarning: invalid value encountered in divide
#   s1 = delta/(value)
# C:\Users\HP\AppData\Local\Temp\ipykernel_20084\3339006431.py:11: RuntimeWarning: invalid value encountered in divide
#   s2 = delta/(2 - value)

# %%
plt.figure("img_saturate")
plt.imshow(img_new)
plt.show()

# %%
img_new.shape
# Out:
# (536, 960, 3)

# %%
img_new2 = cv2.cvtColor( np.array(img_new * 255, dtype=np.uint8), cv2.COLOR_BGR2RGB)

# %%
img_new2 = cv2.cvtColor( np.array(img_new * 255, dtype=np.uint8), cv2.COLOR_BGR2RGB)
cv2.imwrite('./a.png', img_new2)
# Out:
# True
